# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %%
a.reshape(2,2)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a.ndim
# Out:
# 1

# %%
a = sns.load_dataset('iris')
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x = a.petal_length,y = a.petal_width,hue=a.species)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(x = a.petal_length,y = a.petal_width,hue=a.species,palette='plasma')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
a.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
a.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.histplot(a.petal_length)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(a.petal_length,bins=[1,2,3,4,5,6,7,8,9])
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(a.petal_length,bins=[1,2,3,4,5,6,7,8,9],binrange=(0,10))
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
# histo gram using dist plotting
sns.distplot(a.petal_length)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
# now condition is i want only hist plot
sns.distplot(a.petal_length,kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length'>

# %%
sns.displot(x = 'sepal_length', data= a)

# %%
sns.displot(x = 'sepal_length',data=a,kind='kde')

# %%
sns.displot(x = 'sepal_length',data=a)

# %%
# combian hist plot
sns.displot(data=a)

# %%
sns.distplot(a.sepal_length,kde = True,hist=False)
#kdd is used to conctrate the data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.displot(a.sepal_length,kind = 'kde')

# %%
sns.kdeplot(a.sepal_length)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
# When we are used the bivarate the use joint plot
sns.jointplot(a.sepal_length,a.sepal_width)
# it is combination of scatter and hist plot
# on x axis it is sepal lenght and on y axis it is sepal width
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(a.sepal_length,a.petal_width,kind = 'hex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(a.sepal_length,a.petal_width,kind='reg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#categoriwise scatter plot by using joint plots
sns.jointplot(a.sepal_length,a.petal_width,hue=a.species)

# %%
sns.jointplot(a.sepal_length,a.petal_width,hue=a.species,palette='seismic')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# if you want pair relationship then use pair plot
sns.pairplot(data = a)

# %%
sns.pairplot(data = a,hue='species')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_data_home()
# Out:
# 'C:\\Users\\ADMIN\\seaborn-data'

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
a = sns.load_dataset('titanic')
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
row, coloumn = a.shape
print('row is:',row)
print('coloumn is:',coloumn)
# Out:
# row is: 891
# coloumn is: 15

# %%
# find out coloumn name
a.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
a.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
die,live = a.survived.value_counts()
print('total die:',die)
print('total live',live)
# Out:
# total die: 549
# total live 342

# %%
# male how many are dead and how many alive
z = a[a.sex.apply(lambda x:x=='male')]
x = z[z.alive == 'yes'].survived.sum()
print('total alive men is:',x)

f = a.query('alive == "yes" & sex == "female"').survived.sum()
print('total alive women is',f)
# Out:
# total alive men is: 109
# total alive women is 233

# %%
# find total die man and total die women so lets find out
die,coloumn = a.query('sex=="male" & alive == "no"').shape
print('total die male is:',die)
die_women,coloumn = a.query('sex=="female" & alive=="no"').shape
print('total die women is:',die_women)
# Out:
# total die male is: 468
# total die women is: 81

# %%
# a.isnull().sum()
a.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.jointplot(a.fare,a.age)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(x = a.pclass,y = a.age)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.swarmplot(a.pclass,a.age)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.countplot(a.sex)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(a.alive)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='alive', ylabel='count'>

# %%
a.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.countplot(a['class'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
g = sns.FacetGrid(data = a,col='sex')
g.map(sns.distplot,'age',kde = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x = 'sex',hue='survived',kind ='count',data=a)

# %%
#categorywise plotting
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
a = sns.load_dataset('penguins')
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
a.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
a.shape
# Out:
# (344, 7)

# %%
a.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
a.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
a.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# a.bill_length_mm.mean()
a.bill_length_mm = a.bill_length_mm.fillna(43.9055)

# %%
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            41.1            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            41.1            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
a.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
a.bill_depth_mm.mean()
a.bill_depth_mm = a.bill_depth_mm.fillna(43.9055)
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1        18.7000              181.0
# 1    Adelie  Torgersen            39.5        17.4000              186.0
# 2    Adelie  Torgersen            40.3        18.0000              195.0
# 3    Adelie  Torgersen            41.1        43.9055                NaN
# 4    Adelie  Torgersen            36.7        19.3000              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            41.1        43.9055                NaN
# 340  Gentoo     Biscoe            46.8        14.3000              215.0
# 341  Gentoo     Biscoe            50.4        15.7000              222.0
# 342  Gentoo     Biscoe            45.2        14.8000              212.0
# 343  Gentoo     Biscoe            49.9        16.1000              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
a.flipper_length_mm.mean()
a.flipper_length_mm = a.flipper_length_mm.fillna(200.9152)
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1        18.7000           181.0000
# 1    Adelie  Torgersen            39.5        17.4000           186.0000
# 2    Adelie  Torgersen            40.3        18.0000           195.0000
# 3    Adelie  Torgersen            41.1        43.9055           200.9152
# 4    Adelie  Torgersen            36.7        19.3000           193.0000
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            41.1        43.9055           200.9152
# 340  Gentoo     Biscoe            46.8        14.3000           215.0000
# 341  Gentoo     Biscoe            50.4        15.7000           222.0000
# 342  Gentoo     Biscoe            45.2        14.8000           212.0000
# 343  Gentoo     Biscoe            49.9        16.1000           213.0000
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
a.body_mass_g.mean()
a.body_mass_g = a.body_mass_g.fillna(4201.7543)
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1        18.7000           181.0000
# 1    Adelie  Torgersen            39.5        17.4000           186.0000
# 2    Adelie  Torgersen            40.3        18.0000           195.0000
# 3    Adelie  Torgersen            41.1        43.9055           200.9152
# 4    Adelie  Torgersen            36.7        19.3000           193.0000
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            41.1        43.9055           200.9152
# 340  Gentoo     Biscoe            46.8        14.3000           215.0000
# 341  Gentoo     Biscoe            50.4        15.7000           222.0000
# 342  Gentoo     Biscoe            45.2        14.8000           212.0000
# 343  Gentoo     Biscoe            49.9        16.1000           213.0000
#
#      body_mass_g     sex
# 0      3750.0000    Male
# 1      3800.0000  Female
# ...

# %%
a.sex.mode()
a.sex=a.sex.fillna('Male')
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1        18.7000           181.0000
# 1    Adelie  Torgersen            39.5        17.4000           186.0000
# 2    Adelie  Torgersen            40.3        18.0000           195.0000
# 3    Adelie  Torgersen            41.1        43.9055           200.9152
# 4    Adelie  Torgersen            36.7        19.3000           193.0000
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            41.1        43.9055           200.9152
# 340  Gentoo     Biscoe            46.8        14.3000           215.0000
# 341  Gentoo     Biscoe            50.4        15.7000           222.0000
# 342  Gentoo     Biscoe            45.2        14.8000           212.0000
# 343  Gentoo     Biscoe            49.9        16.1000           213.0000
#
#      body_mass_g     sex
# 0      3750.0000    Male
# 1      3800.0000  Female
# ...

# %%
a.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1        18.7000           181.0000
# 1    Adelie  Torgersen            39.5        17.4000           186.0000
# 2    Adelie  Torgersen            40.3        18.0000           195.0000
# 3    Adelie  Torgersen            41.1        43.9055           200.9152
# 4    Adelie  Torgersen            36.7        19.3000           193.0000
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            41.1        43.9055           200.9152
# 340  Gentoo     Biscoe            46.8        14.3000           215.0000
# 341  Gentoo     Biscoe            50.4        15.7000           222.0000
# 342  Gentoo     Biscoe            45.2        14.8000           212.0000
# 343  Gentoo     Biscoe            49.9        16.1000           213.0000
#
#      body_mass_g     sex
# 0      3750.0000    Male
# 1      3800.0000  Female
# ...

# %%
#Draw a scatterplot where one variable is categorical.
# On the basis of Species differentiate with respect to body mass
sns.stripplot(a.species,a.body_mass_g)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
a.species.value_counts().plot.pie(autopct = '%.3f%%')
# Out:
# <AxesSubplot:ylabel='species'>

# %%
# in above plot i want to see genderwise distribustion
sns.stripplot(a.species,a.body_mass_g,hue=a.sex)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(a.species,a.body_mass_g,hue = a.island)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
#load tips dataset as t
t = sns.load_dataset('tips')
t
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\http\client.py:580, in HTTPResponse._readall_chunked(self)
#     579     break
# --> 580 value.append(self._safe_read(chunk_left))
#     581 self.chunk_left = 0
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:628, in HTTPResponse._safe_read(self, amt)
#     627 if not chunk:
# --> 628     raise IncompleteRead(b''.join(s), amt)
#     629 s.append(chunk)
#
# IncompleteRead: IncompleteRead(24654 bytes read, 5226 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# Input In [66], in <cell line: 2>()
#       1 #load tips dataset as t
# ----> 2 t = sns.load_dataset('tips')
#       3 t
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t = sns.load_dataset('tips')
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
t.select_dtypes(['float'])
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
t.select_dtypes(['int','float'])
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
#check some categorical columns
t.smoker.value_counts().plot.pie(autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='smoker'>

# %%
t.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
# check scatter plot with genderwise tip
sns.stripplot(t.sex,t.tip)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(t.sex,t.tip,hue=t.day)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
# genderwise total bill
sns.stripplot(t.sex,t.total_bill)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# ...

# %%
a = sns.load_dataset('penguins')
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
row,coloumn = a.shape
print('row is:',row)
print('coloumn is:',coloumn)
# Out:
# row is: 344
# coloumn is: 7

# %%
print('unique species are:',a.species.unique())
print('unique island are:',a.island.unique())
v = a.species.unique()
b = a.island.unique()
# Out:
# unique species are: ['Adelie' 'Chinstrap' 'Gentoo']
# unique island are: ['Torgersen' 'Biscoe' 'Dream']

# %%
# BY USING SCATTER PLOT WE CAN MAKE A PLOT HAVING ISLAND AND SPECIES
sns.stripplot(a.sex,a.bill_length_mm,hue=a.species)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='bill_length_mm'>

# %%
# how to fill the nan value
a.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# a.bill_length_mm.mean()
# a.bill_length_mm = a.bill_length_mm.fillna(43.9219)
# a


# a.bill_depth_mm.mean()
# a.bill_depth_mm = a.bill_depth_mm.fillna(17.1511)


# a.flipper_length_mm.mean()
# a.flipper_length_mm = a.flipper_length_mm.fillna(200.9152)


# a.body_mass_g.mean()
# a.body_mass_g = a.body_mass_g.fillna(4201.7543)


# a.sex.mode()
# a.sex = a.sex.fillna('Male')

# %%
a
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen         39.1000        18.7000           181.0000
# 1    Adelie  Torgersen         39.5000        17.4000           186.0000
# 2    Adelie  Torgersen         40.3000        18.0000           195.0000
# 3    Adelie  Torgersen         43.9219        17.1511           200.9152
# 4    Adelie  Torgersen         36.7000        19.3000           193.0000
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe         43.9219        17.1511           200.9152
# 340  Gentoo     Biscoe         46.8000        14.3000           215.0000
# 341  Gentoo     Biscoe         50.4000        15.7000           222.0000
# 342  Gentoo     Biscoe         45.2000        14.8000           212.0000
# 343  Gentoo     Biscoe         49.9000        16.1000           213.0000
#
#      body_mass_g     sex
# 0      3750.0000    Male
# 1      3800.0000  Female
# ...

# %%
sns.stripplot()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen         39.1000        18.7000           181.0000
# 1    Adelie  Torgersen         39.5000        17.4000           186.0000
# 2    Adelie  Torgersen         40.3000        18.0000           195.0000
# 3    Adelie  Torgersen         43.9219        17.1511           200.9152
# 4    Adelie  Torgersen         36.7000        19.3000           193.0000
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe         43.9219        17.1511           200.9152
# 340  Gentoo     Biscoe         46.8000        14.3000           215.0000
# 341  Gentoo     Biscoe         50.4000        15.7000           222.0000
# 342  Gentoo     Biscoe         45.2000        14.8000           212.0000
# 343  Gentoo     Biscoe         49.9000        16.1000           213.0000
#
#      body_mass_g     sex
# 0      3750.0000    Male
# 1      3800.0000  Female
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# ...

# %%
a = sns.load_dataset('iris')
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
a.shape
# Out:
# (150, 5)

# %%
a.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
a.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
a.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
a.plot.scatter(x ='petal_length',y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(a.petal_length,a.petal_width,hue=a.species)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
plt.scatter(a.petal_length,a.petal_width,alpha=0.8,marker='o')

# %%
# plottng using seaborn
sns.histplot(data =a,palette='Set2_r')
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(a.sepal_width,bins=5)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.displot(a.sepal_length)

# %%
sns.distplot(a.sepal_length,hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(a.sepal_length,hist=True,kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length'>

# %%
sns.displot(a.sepal_length,kind='kde')

# %%
sns.jointplot(a.sepal_length,a.petal_length,hue=a.species)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(a.petal_length,a.sepal_length,hue=a.species)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = sns.load_dataset('tips')
a.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(a.sex,a.total_bill,hue=a.time)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
z = sns.boxplot(a.day,a.total_bill,hue=a.smoker)
# z.set_title('day vs total bill plot')
# plt.title('day vs total bill')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'day vs total bill')

# %%
# bar plot-use for categorical plot
sns.barplot(a.sex,a.tip,hue=a.time)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
#male give larger tip than female
# tip available at dinner time is larger than lunch
sns.barplot(a.smoker,a['size'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='size'>

# %%
# wihout smoker team member size is larger

# %%
b = sns.load_dataset('titanic')
b
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
b.drop(['survived'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 b.drop(['survived'],axis=1)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
b.drop(labels='sibsp',axis =1)
# Out:
#      pclass     sex   age  parch     fare embarked   class    who  adult_male  \
# 0         3    male  22.0      0   7.2500        S   Third    man        True
# 1         1  female  38.0      0  71.2833        C   First  woman       False
# 2         3  female  26.0      0   7.9250        S   Third  woman       False
# 3         1  female  35.0      0  53.1000        S   First  woman       False
# 4         3    male  35.0      0   8.0500        S   Third    man        True
# ..      ...     ...   ...    ...      ...      ...     ...    ...         ...
# 886       2    male  27.0      0  13.0000        S  Second    man        True
# 887       1  female  19.0      0  30.0000        S   First  woman       False
# 888       3  female   NaN      2  23.4500        S   Third  woman       False
# 889       1    male  26.0      0  30.0000        C   First    man        True
# 890       3    male  32.0      0   7.7500        Q   Third    man        True
#
# ...

# %%
b
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
# here we have to plot the bar graph
# x = sex,class,who,alive,alone
# y = pclass,fare,
sns.barplot(b.sex,b.pclass)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='pclass'>

# %%
sns.barplot(b.sex,b.alive)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 sns.barplot(b.sex,b.alive)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...

# %%
b.alive = b.alive.map({'no':0,'yes':1})

# %%
sns.barplot(b.sex,b.alive,hue=b['class'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='alive'>

# %%
# embarked vs survived
sns.barplot(b.embarked,b.alive)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='embarked', ylabel='alive'>

# %%
#count plot
b.head()
# Out:
#    pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    male  22.0      1      0   7.2500        S  Third    man
# 1       1  female  38.0      1      0  71.2833        C  First  woman
# 2       3  female  26.0      0      0   7.9250        S  Third  woman
# 3       1  female  35.0      1      0  53.1000        S  First  woman
# 4       3    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True  NaN  Southampton      0  False
# 1       False    C    Cherbourg      1  False
# 2       False  NaN  Southampton      1   True
# 3       False    C  Southampton      1  False
# 4        True  NaN  Southampton      0   True

# %%
b.sex.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(b.sex,hue=b['class'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(b.sex,hue=b['alive','class'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('alive', 'class')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sns.violinplot(b.sex,b.age,hue=b['class'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# ...

# %%
a = sns.load_dataset('iris')
a[:3]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
a.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
a.species.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(a.sepal_length,a.petal_length,hue=a.species)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
a.shape
# Out:
# (150, 5)

# %%
a.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
a.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(a.petal_length,a.petal_width,hue=a.species,palette='Wistia')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>
